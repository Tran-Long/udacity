# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** The CNN-RNN model which I am using contains an encoder and a decoder. The encoder is a CNN-based model, which use resnet50 as the backbone and output a features with size of embed_size. The decoder is a RNN-based model, which use 1 LSTM layer and a linear layer to output predictions of words. The image will be fed into the encoder to produce features, and then the features will be fed into the decoder to generate caption. I chose value for hyperparameters in Task 1 after experimenting with few modifications.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I left the transform_train as-is. I think that with defined random crop and horizontal flip, the training of my CNN will perform well without overfitting. Besides, the normalizing value is based on the normalizing value of resnet50 model, which I use as the backbone of the CNN-model
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** I select all parameters in the encoder and the decoder as trainable parameters except those in the resnet50 backbone of the encoder. I froze it because I think the pretrained weights of resnet50 is fine to output features of images.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**  For optimization function, I use Adam algorithm with default value. Adam inherit the features of both Adagrad and RMS prop algorithms so it performs better in most cases. I tried with few modification to the lr and it showed that the default value perform best

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 4        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
#   0%|          | 797/414113 [00:00<01:40, 4093.65it/s]
# Done (t=0.91s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:36<00:00, 4298.03it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/12942], Loss: 3.8546, Perplexity: 47.2081
# Epoch [1/3], Step [200/12942], Loss: 3.5435, Perplexity: 34.5893
# Epoch [1/3], Step [300/12942], Loss: 3.1785, Perplexity: 24.01136
# Epoch [1/3], Step [400/12942], Loss: 3.6502, Perplexity: 38.4832
# Epoch [1/3], Step [500/12942], Loss: 3.3969, Perplexity: 29.8724
# Epoch [1/3], Step [600/12942], Loss: 3.3581, Perplexity: 28.7333
# Epoch [1/3], Step [700/12942], Loss: 2.8707, Perplexity: 17.6501
# Epoch [1/3], Step [800/12942], Loss: 3.2699, Perplexity: 26.3085
# Epoch [1/3], Step [900/12942], Loss: 3.0924, Perplexity: 22.0303
# Epoch [1/3], Step [1000/12942], Loss: 3.1609, Perplexity: 23.5927
# Epoch [1/3], Step [1100/12942], Loss: 3.1782, Perplexity: 24.0034
# Epoch [1/3], Step [1200/12942], Loss: 3.0125, Perplexity: 20.3377
# Epoch [1/3], Step [1300/12942], Loss: 3.3794, Perplexity: 29.3545
# Epoch [1/3], Step [1400/12942], Loss: 2.7510, Perplexity: 15.6579
# Epoch [1/3], Step [1500/12942], Loss: 2.8989, Perplexity: 18.1539
# Epoch [1/3], Step [1600/12942], Loss: 3.2536, Perplexity: 25.8837
# Epoch [1/3], Step [1700/12942], Loss: 2.5497, Perplexity: 12.8031
# Epoch [1/3], Step [1800/12942], Loss: 2.3885, Perplexity: 10.8972
# Epoch [1/3], Step [1900/12942], Loss: 3.0285, Perplexity: 20.6669
# Epoch [1/3], Step [2000/12942], Loss: 2.7271, Perplexity: 15.2891
# Epoch [1/3], Step [2100/12942], Loss: 2.8720, Perplexity: 17.6716
# Epoch [1/3], Step [2200/12942], Loss: 2.5978, Perplexity: 13.4342
# Epoch [1/3], Step [2300/12942], Loss: 2.6854, Perplexity: 14.6648
# Epoch [1/3], Step [2400/12942], Loss: 2.4902, Perplexity: 12.0632
# Epoch [1/3], Step [2500/12942], Loss: 3.0834, Perplexity: 21.8324
# Epoch [1/3], Step [2600/12942], Loss: 2.7631, Perplexity: 15.8485
# Epoch [1/3], Step [2700/12942], Loss: 2.3424, Perplexity: 10.4065
# Epoch [1/3], Step [2800/12942], Loss: 2.8088, Perplexity: 16.5908
# Epoch [1/3], Step [2900/12942], Loss: 2.5780, Perplexity: 13.1712
# Epoch [1/3], Step [3000/12942], Loss: 2.1356, Perplexity: 8.46218
# Epoch [1/3], Step [3100/12942], Loss: 2.5438, Perplexity: 12.72739
# Epoch [1/3], Step [3200/12942], Loss: 2.1945, Perplexity: 8.97538
# Epoch [1/3], Step [3300/12942], Loss: 2.6429, Perplexity: 14.05331
# Epoch [1/3], Step [3400/12942], Loss: 2.6083, Perplexity: 13.5755
# Epoch [1/3], Step [3500/12942], Loss: 2.5204, Perplexity: 12.4332
# Epoch [1/3], Step [3600/12942], Loss: 2.5822, Perplexity: 13.2268
# Epoch [1/3], Step [3700/12942], Loss: 2.6391, Perplexity: 14.0013
# Epoch [1/3], Step [3800/12942], Loss: 2.8616, Perplexity: 17.4902
# Epoch [1/3], Step [3900/12942], Loss: 2.3162, Perplexity: 10.1375
# Epoch [1/3], Step [4000/12942], Loss: 2.3464, Perplexity: 10.44822
# Epoch [1/3], Step [4100/12942], Loss: 2.4401, Perplexity: 11.4737
# Epoch [1/3], Step [4200/12942], Loss: 2.3334, Perplexity: 10.3125
# Epoch [1/3], Step [4300/12942], Loss: 2.6475, Perplexity: 14.1192
# Epoch [1/3], Step [4400/12942], Loss: 2.5395, Perplexity: 12.6735
# Epoch [1/3], Step [4500/12942], Loss: 2.6081, Perplexity: 13.5728
# Epoch [1/3], Step [4600/12942], Loss: 2.4097, Perplexity: 11.1311
# Epoch [1/3], Step [4700/12942], Loss: 2.2853, Perplexity: 9.82876
# Epoch [1/3], Step [4800/12942], Loss: 2.5635, Perplexity: 12.9810
# Epoch [1/3], Step [4900/12942], Loss: 2.4918, Perplexity: 12.0831
# Epoch [1/3], Step [5000/12942], Loss: 2.1021, Perplexity: 8.18367
# Epoch [1/3], Step [5100/12942], Loss: 2.4040, Perplexity: 11.0677
# Epoch [1/3], Step [5200/12942], Loss: 2.4366, Perplexity: 11.4339
# Epoch [1/3], Step [5300/12942], Loss: 2.1301, Perplexity: 8.41539
# Epoch [1/3], Step [5400/12942], Loss: 2.2925, Perplexity: 9.90004
# Epoch [1/3], Step [5500/12942], Loss: 2.3024, Perplexity: 9.99805
# Epoch [1/3], Step [5600/12942], Loss: 2.0482, Perplexity: 7.75409
# Epoch [1/3], Step [5700/12942], Loss: 2.2344, Perplexity: 9.34095
# Epoch [1/3], Step [5800/12942], Loss: 2.9613, Perplexity: 19.3240
# Epoch [1/3], Step [5900/12942], Loss: 2.2113, Perplexity: 9.127624
# Epoch [1/3], Step [6000/12942], Loss: 2.3234, Perplexity: 10.2099
# Epoch [1/3], Step [6100/12942], Loss: 2.6684, Perplexity: 14.4174
# Epoch [1/3], Step [6200/12942], Loss: 2.0410, Perplexity: 7.69823
# Epoch [1/3], Step [6300/12942], Loss: 2.2626, Perplexity: 9.60823
# Epoch [1/3], Step [6400/12942], Loss: 2.6060, Perplexity: 13.5444
# Epoch [1/3], Step [6500/12942], Loss: 2.1077, Perplexity: 8.22967
# Epoch [1/3], Step [6600/12942], Loss: 2.4218, Perplexity: 11.2659
# Epoch [1/3], Step [6700/12942], Loss: 2.0537, Perplexity: 7.79671
# Epoch [1/3], Step [6800/12942], Loss: 3.0642, Perplexity: 21.4182
# Epoch [1/3], Step [6900/12942], Loss: 2.3749, Perplexity: 10.7495
# Epoch [1/3], Step [7000/12942], Loss: 2.5715, Perplexity: 13.0855
# Epoch [1/3], Step [7100/12942], Loss: 2.4747, Perplexity: 11.8783
# Epoch [1/3], Step [7200/12942], Loss: 1.9904, Perplexity: 7.31849
# Epoch [1/3], Step [7300/12942], Loss: 2.2456, Perplexity: 9.44566
# Epoch [1/3], Step [7400/12942], Loss: 2.2821, Perplexity: 9.79773
# Epoch [1/3], Step [7500/12942], Loss: 2.2303, Perplexity: 9.302332
# Epoch [1/3], Step [7600/12942], Loss: 2.6145, Perplexity: 13.6607
# Epoch [1/3], Step [7700/12942], Loss: 2.3661, Perplexity: 10.6556
# Epoch [1/3], Step [7800/12942], Loss: 2.1657, Perplexity: 8.72098
# Epoch [1/3], Step [7900/12942], Loss: 2.3965, Perplexity: 10.9845
# Epoch [1/3], Step [8000/12942], Loss: 2.0091, Perplexity: 7.45646
# Epoch [1/3], Step [8100/12942], Loss: 2.4539, Perplexity: 11.6333
# Epoch [1/3], Step [8200/12942], Loss: 2.5187, Perplexity: 12.4124
# Epoch [1/3], Step [8300/12942], Loss: 2.1812, Perplexity: 8.85670
# Epoch [1/3], Step [8400/12942], Loss: 2.3761, Perplexity: 10.7633
# Epoch [1/3], Step [8500/12942], Loss: 1.8704, Perplexity: 6.49126
# Epoch [1/3], Step [8600/12942], Loss: 2.3666, Perplexity: 10.6611
# Epoch [1/3], Step [8700/12942], Loss: 2.2379, Perplexity: 9.37376
# Epoch [1/3], Step [8800/12942], Loss: 2.2958, Perplexity: 9.93234
# Epoch [1/3], Step [8900/12942], Loss: 2.4119, Perplexity: 11.1553
# Epoch [1/3], Step [9000/12942], Loss: 2.1478, Perplexity: 8.56587
# Epoch [1/3], Step [9100/12942], Loss: 2.0521, Perplexity: 7.78468
# Epoch [1/3], Step [9200/12942], Loss: 2.1152, Perplexity: 8.29154
# Epoch [1/3], Step [9300/12942], Loss: 1.9471, Perplexity: 7.00847
# Epoch [1/3], Step [9400/12942], Loss: 2.0095, Perplexity: 7.45976
# Epoch [1/3], Step [9500/12942], Loss: 2.1063, Perplexity: 8.21803
# Epoch [1/3], Step [9600/12942], Loss: 2.3831, Perplexity: 10.8381
# Epoch [1/3], Step [9700/12942], Loss: 2.1234, Perplexity: 8.35984
# Epoch [1/3], Step [9800/12942], Loss: 2.6189, Perplexity: 13.7210
# Epoch [1/3], Step [9900/12942], Loss: 2.1527, Perplexity: 8.60806
# Epoch [1/3], Step [10000/12942], Loss: 1.9958, Perplexity: 7.3584
# Epoch [1/3], Step [10100/12942], Loss: 2.1575, Perplexity: 8.64912
# Epoch [1/3], Step [10200/12942], Loss: 2.2199, Perplexity: 9.20606
# Epoch [1/3], Step [10300/12942], Loss: 2.0654, Perplexity: 7.88838
# Epoch [1/3], Step [10400/12942], Loss: 2.1361, Perplexity: 8.46670
# Epoch [1/3], Step [10500/12942], Loss: 2.0650, Perplexity: 7.88518
# Epoch [1/3], Step [10600/12942], Loss: 2.0543, Perplexity: 7.80174
# Epoch [1/3], Step [10700/12942], Loss: 2.1362, Perplexity: 8.46700
# Epoch [1/3], Step [10800/12942], Loss: 2.2342, Perplexity: 9.33901
# Epoch [1/3], Step [10900/12942], Loss: 2.2627, Perplexity: 9.60896
# Epoch [1/3], Step [11000/12942], Loss: 2.2260, Perplexity: 9.26272
# Epoch [1/3], Step [11100/12942], Loss: 2.2386, Perplexity: 9.38014
# Epoch [1/3], Step [11200/12942], Loss: 2.1285, Perplexity: 8.40265
# Epoch [1/3], Step [11300/12942], Loss: 2.3534, Perplexity: 10.5213
# Epoch [1/3], Step [11400/12942], Loss: 2.3236, Perplexity: 10.2120
# Epoch [1/3], Step [11500/12942], Loss: 2.2746, Perplexity: 9.72430
# Epoch [1/3], Step [11600/12942], Loss: 2.0670, Perplexity: 7.90120
# Epoch [1/3], Step [11700/12942], Loss: 2.3339, Perplexity: 10.3178
# Epoch [1/3], Step [11800/12942], Loss: 2.0691, Perplexity: 7.91769
# Epoch [1/3], Step [11900/12942], Loss: 2.2108, Perplexity: 9.12347
# Epoch [1/3], Step [12000/12942], Loss: 2.6464, Perplexity: 14.1029
# Epoch [1/3], Step [12100/12942], Loss: 2.1070, Perplexity: 8.22331
# Epoch [1/3], Step [12200/12942], Loss: 2.1948, Perplexity: 8.97861
# Epoch [1/3], Step [12300/12942], Loss: 2.0820, Perplexity: 8.02035
# Epoch [1/3], Step [12400/12942], Loss: 2.4980, Perplexity: 12.1577
# Epoch [1/3], Step [12500/12942], Loss: 2.5486, Perplexity: 12.7891
# Epoch [1/3], Step [12600/12942], Loss: 2.0136, Perplexity: 7.48997
# Epoch [1/3], Step [12700/12942], Loss: 2.5981, Perplexity: 13.4377
# Epoch [1/3], Step [12800/12942], Loss: 2.0123, Perplexity: 7.48082
# Epoch [1/3], Step [12900/12942], Loss: 2.1186, Perplexity: 8.31939
# Epoch [2/3], Step [100/12942], Loss: 2.0219, Perplexity: 7.5529363
# Epoch [2/3], Step [200/12942], Loss: 2.1342, Perplexity: 8.45030
# Epoch [2/3], Step [300/12942], Loss: 2.0122, Perplexity: 7.47944
# Epoch [2/3], Step [400/12942], Loss: 2.1951, Perplexity: 8.98070
# Epoch [2/3], Step [500/12942], Loss: 2.3233, Perplexity: 10.2095
# Epoch [2/3], Step [600/12942], Loss: 2.5368, Perplexity: 12.6392
# Epoch [2/3], Step [700/12942], Loss: 2.0848, Perplexity: 8.04297
# Epoch [2/3], Step [800/12942], Loss: 2.1096, Perplexity: 8.24528
# Epoch [2/3], Step [900/12942], Loss: 2.1367, Perplexity: 8.47184
# Epoch [2/3], Step [1000/12942], Loss: 2.0948, Perplexity: 8.1242
# Epoch [2/3], Step [1100/12942], Loss: 2.1964, Perplexity: 8.99223
# Epoch [2/3], Step [1200/12942], Loss: 2.3850, Perplexity: 10.8595
# Epoch [2/3], Step [1300/12942], Loss: 2.2051, Perplexity: 9.07127
# Epoch [2/3], Step [1400/12942], Loss: 2.1939, Perplexity: 8.96987
# Epoch [2/3], Step [1500/12942], Loss: 2.3721, Perplexity: 10.7194
# Epoch [2/3], Step [1600/12942], Loss: 2.1308, Perplexity: 8.42163
# Epoch [2/3], Step [1700/12942], Loss: 2.2562, Perplexity: 9.54663
# Epoch [2/3], Step [1800/12942], Loss: 1.9596, Perplexity: 7.09613
# Epoch [2/3], Step [1900/12942], Loss: 1.7966, Perplexity: 6.02929
# Epoch [2/3], Step [2000/12942], Loss: 2.0714, Perplexity: 7.93576
# Epoch [2/3], Step [2100/12942], Loss: 1.9633, Perplexity: 7.12273
# Epoch [2/3], Step [2200/12942], Loss: 1.9634, Perplexity: 7.12360
# Epoch [2/3], Step [2300/12942], Loss: 1.8622, Perplexity: 6.43800
# Epoch [2/3], Step [2400/12942], Loss: 2.0600, Perplexity: 7.84619
# Epoch [2/3], Step [2500/12942], Loss: 2.1297, Perplexity: 8.41213
# Epoch [2/3], Step [2600/12942], Loss: 2.1710, Perplexity: 8.76687
# Epoch [2/3], Step [2700/12942], Loss: 2.3577, Perplexity: 10.5670
# Epoch [2/3], Step [2800/12942], Loss: 2.1785, Perplexity: 8.83292
# Epoch [2/3], Step [2900/12942], Loss: 2.3161, Perplexity: 10.1362
# Epoch [2/3], Step [3000/12942], Loss: 2.1314, Perplexity: 8.42706
# Epoch [2/3], Step [3100/12942], Loss: 2.1669, Perplexity: 8.73098
# Epoch [2/3], Step [3200/12942], Loss: 2.0444, Perplexity: 7.72441
# Epoch [2/3], Step [3300/12942], Loss: 2.2213, Perplexity: 9.21899
# Epoch [2/3], Step [3400/12942], Loss: 2.0737, Perplexity: 7.95418
# Epoch [2/3], Step [3500/12942], Loss: 1.9279, Perplexity: 6.87483
# Epoch [2/3], Step [3600/12942], Loss: 2.0199, Perplexity: 7.53753
# Epoch [2/3], Step [3700/12942], Loss: 2.1369, Perplexity: 8.47303
# Epoch [2/3], Step [3800/12942], Loss: 2.2290, Perplexity: 9.29072
# Epoch [2/3], Step [3900/12942], Loss: 2.0782, Perplexity: 7.99041
# Epoch [2/3], Step [4000/12942], Loss: 2.2710, Perplexity: 9.68892
# Epoch [2/3], Step [4100/12942], Loss: 2.2205, Perplexity: 9.21206
# Epoch [2/3], Step [4200/12942], Loss: 1.9998, Perplexity: 7.38744
# Epoch [2/3], Step [4300/12942], Loss: 1.9853, Perplexity: 7.28157
# Epoch [2/3], Step [4400/12942], Loss: 1.9923, Perplexity: 7.33242
# Epoch [2/3], Step [4500/12942], Loss: 2.6823, Perplexity: 14.6185
# Epoch [2/3], Step [4600/12942], Loss: 2.0304, Perplexity: 7.61756
# Epoch [2/3], Step [4700/12942], Loss: 2.0597, Perplexity: 7.84344
# Epoch [2/3], Step [4800/12942], Loss: 2.1870, Perplexity: 8.908496
# Epoch [2/3], Step [4900/12942], Loss: 2.0589, Perplexity: 7.83745
# Epoch [2/3], Step [5000/12942], Loss: 2.2239, Perplexity: 9.24344
# Epoch [2/3], Step [5100/12942], Loss: 2.3177, Perplexity: 10.1521
# Epoch [2/3], Step [5200/12942], Loss: 2.0552, Perplexity: 7.80824
# Epoch [2/3], Step [5300/12942], Loss: 1.9718, Perplexity: 7.18379
# Epoch [2/3], Step [5400/12942], Loss: 2.0725, Perplexity: 7.94455
# Epoch [2/3], Step [5500/12942], Loss: 2.1935, Perplexity: 8.96646
# Epoch [2/3], Step [5600/12942], Loss: 1.9799, Perplexity: 7.24225
# Epoch [2/3], Step [5700/12942], Loss: 2.1981, Perplexity: 9.00820
# Epoch [2/3], Step [5800/12942], Loss: 2.0389, Perplexity: 7.68203
# Epoch [2/3], Step [5900/12942], Loss: 1.7785, Perplexity: 5.92082
# Epoch [2/3], Step [6000/12942], Loss: 2.2483, Perplexity: 9.47179
# Epoch [2/3], Step [6100/12942], Loss: 2.2114, Perplexity: 9.12846
# Epoch [2/3], Step [6200/12942], Loss: 1.9844, Perplexity: 7.27509
# Epoch [2/3], Step [6300/12942], Loss: 2.2282, Perplexity: 9.28316
# Epoch [2/3], Step [6400/12942], Loss: 2.7846, Perplexity: 16.1936
# Epoch [2/3], Step [6500/12942], Loss: 2.0254, Perplexity: 7.57888
# Epoch [2/3], Step [6600/12942], Loss: 2.0637, Perplexity: 7.87516
# Epoch [2/3], Step [6700/12942], Loss: 2.3152, Perplexity: 10.1270
# Epoch [2/3], Step [6800/12942], Loss: 2.1658, Perplexity: 8.72154
# Epoch [2/3], Step [6900/12942], Loss: 2.3957, Perplexity: 10.9758
# Epoch [2/3], Step [7000/12942], Loss: 2.3519, Perplexity: 10.5056
# Epoch [2/3], Step [7100/12942], Loss: 2.0773, Perplexity: 7.982675
# Epoch [2/3], Step [7200/12942], Loss: 2.1514, Perplexity: 8.59725
# Epoch [2/3], Step [7300/12942], Loss: 2.2842, Perplexity: 9.81752
# Epoch [2/3], Step [7400/12942], Loss: 2.1594, Perplexity: 8.66607
# Epoch [2/3], Step [7500/12942], Loss: 2.0072, Perplexity: 7.44275
# Epoch [2/3], Step [7600/12942], Loss: 2.2630, Perplexity: 9.61181
# Epoch [2/3], Step [7700/12942], Loss: 2.0242, Perplexity: 7.57015
# Epoch [2/3], Step [7800/12942], Loss: 2.1515, Perplexity: 8.59783
# Epoch [2/3], Step [7900/12942], Loss: 2.1302, Perplexity: 8.41667
# Epoch [2/3], Step [8000/12942], Loss: 2.2016, Perplexity: 9.03943
# Epoch [2/3], Step [8100/12942], Loss: 1.9740, Perplexity: 7.19969
# Epoch [2/3], Step [8200/12942], Loss: 2.2793, Perplexity: 9.76945
# Epoch [2/3], Step [8300/12942], Loss: 2.2204, Perplexity: 9.21123
# Epoch [2/3], Step [8400/12942], Loss: 2.1424, Perplexity: 8.51967
# Epoch [2/3], Step [8500/12942], Loss: 2.0159, Perplexity: 7.50756
# Epoch [2/3], Step [8600/12942], Loss: 2.1241, Perplexity: 8.36547
# Epoch [2/3], Step [8700/12942], Loss: 2.5561, Perplexity: 12.8852
# Epoch [2/3], Step [8800/12942], Loss: 2.0177, Perplexity: 7.52096
# Epoch [2/3], Step [8900/12942], Loss: 1.9583, Perplexity: 7.08763
# Epoch [2/3], Step [9000/12942], Loss: 2.1087, Perplexity: 8.23710
# Epoch [2/3], Step [9100/12942], Loss: 2.4800, Perplexity: 11.9416
# Epoch [2/3], Step [9200/12942], Loss: 2.1577, Perplexity: 8.65090
# Epoch [2/3], Step [9300/12942], Loss: 2.0568, Perplexity: 7.82089
# Epoch [2/3], Step [9400/12942], Loss: 1.9883, Perplexity: 7.30313
# Epoch [2/3], Step [9500/12942], Loss: 2.1627, Perplexity: 8.69495
# Epoch [2/3], Step [9600/12942], Loss: 2.0605, Perplexity: 7.84970
# Epoch [2/3], Step [9700/12942], Loss: 2.2234, Perplexity: 9.23897
# Epoch [2/3], Step [9800/12942], Loss: 2.0649, Perplexity: 7.88454
# Epoch [2/3], Step [9900/12942], Loss: 2.1823, Perplexity: 8.86662
# Epoch [2/3], Step [10000/12942], Loss: 2.5575, Perplexity: 12.9033
# Epoch [2/3], Step [10100/12942], Loss: 2.3573, Perplexity: 10.5625
# Epoch [2/3], Step [10200/12942], Loss: 2.3683, Perplexity: 10.6787
# Epoch [2/3], Step [10300/12942], Loss: 2.4343, Perplexity: 11.4082
# Epoch [2/3], Step [10400/12942], Loss: 2.2878, Perplexity: 9.85301
# Epoch [2/3], Step [10500/12942], Loss: 2.0175, Perplexity: 7.51964
# Epoch [2/3], Step [10600/12942], Loss: 2.3354, Perplexity: 10.3337
# Epoch [2/3], Step [10700/12942], Loss: 2.5909, Perplexity: 13.3414
# Epoch [2/3], Step [10800/12942], Loss: 1.8856, Perplexity: 6.59040
# Epoch [2/3], Step [10900/12942], Loss: 2.0404, Perplexity: 7.69347
# Epoch [2/3], Step [11000/12942], Loss: 2.0725, Perplexity: 7.94479
# Epoch [2/3], Step [11100/12942], Loss: 2.1782, Perplexity: 8.83002
# Epoch [2/3], Step [11200/12942], Loss: 2.3941, Perplexity: 10.9580
# Epoch [2/3], Step [11300/12942], Loss: 2.1372, Perplexity: 8.47578
# Epoch [2/3], Step [11400/12942], Loss: 2.2246, Perplexity: 9.25029
# Epoch [2/3], Step [11500/12942], Loss: 2.5231, Perplexity: 12.4672
# Epoch [2/3], Step [11600/12942], Loss: 2.3365, Perplexity: 10.3452
# Epoch [2/3], Step [11700/12942], Loss: 1.8635, Perplexity: 6.44629
# Epoch [2/3], Step [11800/12942], Loss: 1.9150, Perplexity: 6.78716
# Epoch [2/3], Step [11900/12942], Loss: 2.3541, Perplexity: 10.5287
# Epoch [2/3], Step [12000/12942], Loss: 2.2533, Perplexity: 9.51865
# Epoch [2/3], Step [12100/12942], Loss: 2.0879, Perplexity: 8.06809
# Epoch [2/3], Step [12200/12942], Loss: 1.8939, Perplexity: 6.64506
# Epoch [2/3], Step [12300/12942], Loss: 1.9600, Perplexity: 7.09949
# Epoch [2/3], Step [12400/12942], Loss: 1.7647, Perplexity: 5.83995
# Epoch [2/3], Step [12500/12942], Loss: 2.2767, Perplexity: 9.74444
# Epoch [2/3], Step [12600/12942], Loss: 2.2885, Perplexity: 9.85997
# Epoch [2/3], Step [12700/12942], Loss: 2.3464, Perplexity: 10.4474
# Epoch [2/3], Step [12800/12942], Loss: 2.1427, Perplexity: 8.52272
# Epoch [2/3], Step [12900/12942], Loss: 2.3775, Perplexity: 10.7774
# Epoch [3/3], Step [100/12942], Loss: 1.9258, Perplexity: 6.8610900
# Epoch [3/3], Step [200/12942], Loss: 2.2776, Perplexity: 9.75330
# Epoch [3/3], Step [300/12942], Loss: 2.0123, Perplexity: 7.48051
# Epoch [3/3], Step [400/12942], Loss: 2.0628, Perplexity: 7.86828
# Epoch [3/3], Step [500/12942], Loss: 2.3337, Perplexity: 10.3162
# Epoch [3/3], Step [600/12942], Loss: 1.9081, Perplexity: 6.74029
# Epoch [3/3], Step [700/12942], Loss: 1.9357, Perplexity: 6.92889
# Epoch [3/3], Step [800/12942], Loss: 2.0389, Perplexity: 7.68242
# Epoch [3/3], Step [900/12942], Loss: 2.0353, Perplexity: 7.65434
# Epoch [3/3], Step [1000/12942], Loss: 1.9182, Perplexity: 6.8084
# Epoch [3/3], Step [1100/12942], Loss: 2.2337, Perplexity: 9.33466
# Epoch [3/3], Step [1200/12942], Loss: 1.8307, Perplexity: 6.23810
# Epoch [3/3], Step [1300/12942], Loss: 2.3587, Perplexity: 10.5770
# Epoch [3/3], Step [1400/12942], Loss: 1.8950, Perplexity: 6.65225
# Epoch [3/3], Step [1500/12942], Loss: 1.9732, Perplexity: 7.19362
# Epoch [3/3], Step [1600/12942], Loss: 2.1424, Perplexity: 8.51994
# Epoch [3/3], Step [1700/12942], Loss: 2.0806, Perplexity: 8.00905
# Epoch [3/3], Step [1800/12942], Loss: 1.8836, Perplexity: 6.57748
# Epoch [3/3], Step [1900/12942], Loss: 1.9588, Perplexity: 7.09100
# Epoch [3/3], Step [2000/12942], Loss: 2.1294, Perplexity: 8.40988
# Epoch [3/3], Step [2100/12942], Loss: 2.1476, Perplexity: 8.56405
# Epoch [3/3], Step [2200/12942], Loss: 1.8350, Perplexity: 6.26539
# Epoch [3/3], Step [2300/12942], Loss: 2.2619, Perplexity: 9.60099
# Epoch [3/3], Step [2400/12942], Loss: 2.7589, Perplexity: 15.7822
# Epoch [3/3], Step [2500/12942], Loss: 2.0783, Perplexity: 7.99087
# Epoch [3/3], Step [2600/12942], Loss: 2.2668, Perplexity: 9.64821
# Epoch [3/3], Step [2700/12942], Loss: 1.9972, Perplexity: 7.36816
# Epoch [3/3], Step [2800/12942], Loss: 2.1056, Perplexity: 8.21183
# Epoch [3/3], Step [2900/12942], Loss: 2.3712, Perplexity: 10.7107
# Epoch [3/3], Step [3000/12942], Loss: 1.9660, Perplexity: 7.14235
# Epoch [3/3], Step [3100/12942], Loss: 2.0262, Perplexity: 7.58548
# Epoch [3/3], Step [3200/12942], Loss: 1.8856, Perplexity: 6.59031
# Epoch [3/3], Step [3300/12942], Loss: 2.1439, Perplexity: 8.53278
# Epoch [3/3], Step [3400/12942], Loss: 1.9550, Perplexity: 7.06375
# Epoch [3/3], Step [3500/12942], Loss: 2.2308, Perplexity: 9.30710
# Epoch [3/3], Step [3600/12942], Loss: 2.0624, Perplexity: 7.86493
# Epoch [3/3], Step [3700/12942], Loss: 2.2371, Perplexity: 9.36658
# Epoch [3/3], Step [3800/12942], Loss: 1.9762, Perplexity: 7.21510
# Epoch [3/3], Step [3900/12942], Loss: 2.0997, Perplexity: 8.16396
# Epoch [3/3], Step [4000/12942], Loss: 1.7933, Perplexity: 6.00929
# Epoch [3/3], Step [4100/12942], Loss: 1.9886, Perplexity: 7.30575
# Epoch [3/3], Step [4200/12942], Loss: 2.1782, Perplexity: 8.83037
# Epoch [3/3], Step [4300/12942], Loss: 1.7984, Perplexity: 6.03988
# Epoch [3/3], Step [4400/12942], Loss: 1.8649, Perplexity: 6.45502
# Epoch [3/3], Step [4500/12942], Loss: 1.7203, Perplexity: 5.58652
# Epoch [3/3], Step [4600/12942], Loss: 2.0633, Perplexity: 7.87221
# Epoch [3/3], Step [4700/12942], Loss: 2.3592, Perplexity: 10.5821
# Epoch [3/3], Step [4800/12942], Loss: 2.3201, Perplexity: 10.1766
# Epoch [3/3], Step [4900/12942], Loss: 1.9874, Perplexity: 7.29645
# Epoch [3/3], Step [5000/12942], Loss: 2.1260, Perplexity: 8.38119
# Epoch [3/3], Step [5100/12942], Loss: 2.1333, Perplexity: 8.44277
# Epoch [3/3], Step [5200/12942], Loss: 2.0868, Perplexity: 8.05872
# Epoch [3/3], Step [5300/12942], Loss: 1.8460, Perplexity: 6.33477
# Epoch [3/3], Step [5400/12942], Loss: 1.8201, Perplexity: 6.17251
# Epoch [3/3], Step [5500/12942], Loss: 2.2722, Perplexity: 9.70038
# Epoch [3/3], Step [5600/12942], Loss: 1.8678, Perplexity: 6.47415
# Epoch [3/3], Step [5700/12942], Loss: 1.6764, Perplexity: 5.34653
# Epoch [3/3], Step [5800/12942], Loss: 2.8762, Perplexity: 17.7473
# Epoch [3/3], Step [5900/12942], Loss: 1.7892, Perplexity: 5.98452
# Epoch [3/3], Step [6000/12942], Loss: 2.0139, Perplexity: 7.49258
# Epoch [3/3], Step [6100/12942], Loss: 2.0899, Perplexity: 8.08382
# Epoch [3/3], Step [6200/12942], Loss: 2.1810, Perplexity: 8.85549
# Epoch [3/3], Step [6300/12942], Loss: 2.0491, Perplexity: 7.76079
# Epoch [3/3], Step [6400/12942], Loss: 1.9364, Perplexity: 6.93373
# Epoch [3/3], Step [6500/12942], Loss: 2.1357, Perplexity: 8.46303
# Epoch [3/3], Step [6600/12942], Loss: 2.0861, Perplexity: 8.05315
# Epoch [3/3], Step [6700/12942], Loss: 2.1414, Perplexity: 8.51107
# Epoch [3/3], Step [6800/12942], Loss: 2.1009, Perplexity: 8.17360
# Epoch [3/3], Step [6900/12942], Loss: 2.0585, Perplexity: 7.83462
# Epoch [3/3], Step [7000/12942], Loss: 1.8919, Perplexity: 6.63161
# Epoch [3/3], Step [7100/12942], Loss: 1.8741, Perplexity: 6.51494
# Epoch [3/3], Step [7200/12942], Loss: 1.7829, Perplexity: 5.94715
# Epoch [3/3], Step [7300/12942], Loss: 2.0444, Perplexity: 7.72458
# Epoch [3/3], Step [7400/12942], Loss: 2.2092, Perplexity: 9.108494
# Epoch [3/3], Step [7500/12942], Loss: 1.9549, Perplexity: 7.06313
# Epoch [3/3], Step [7600/12942], Loss: 2.3178, Perplexity: 10.1531
# Epoch [3/3], Step [7700/12942], Loss: 2.1015, Perplexity: 8.17814
# Epoch [3/3], Step [7800/12942], Loss: 2.0974, Perplexity: 8.14462
# Epoch [3/3], Step [7900/12942], Loss: 2.0263, Perplexity: 7.58588
# Epoch [3/3], Step [8000/12942], Loss: 1.8837, Perplexity: 6.57804
# Epoch [3/3], Step [8100/12942], Loss: 1.8868, Perplexity: 6.59831
# Epoch [3/3], Step [8200/12942], Loss: 1.8829, Perplexity: 6.57238
# Epoch [3/3], Step [8300/12942], Loss: 2.0027, Perplexity: 7.40926
# Epoch [3/3], Step [8400/12942], Loss: 2.1483, Perplexity: 8.57007
# Epoch [3/3], Step [8500/12942], Loss: 1.9556, Perplexity: 7.06812
# Epoch [3/3], Step [8600/12942], Loss: 2.0178, Perplexity: 7.52176
# Epoch [3/3], Step [8700/12942], Loss: 2.1158, Perplexity: 8.29649
# Epoch [3/3], Step [8800/12942], Loss: 2.0367, Perplexity: 7.66499
# Epoch [3/3], Step [8900/12942], Loss: 1.8602, Perplexity: 6.42515
# Epoch [3/3], Step [9000/12942], Loss: 1.7156, Perplexity: 5.56012
# Epoch [3/3], Step [9100/12942], Loss: 2.1686, Perplexity: 8.74639
# Epoch [3/3], Step [9200/12942], Loss: 1.8898, Perplexity: 6.61770
# Epoch [3/3], Step [9300/12942], Loss: 2.0797, Perplexity: 8.00214
# Epoch [3/3], Step [9400/12942], Loss: 2.4055, Perplexity: 11.08380
# Epoch [3/3], Step [9500/12942], Loss: 1.8291, Perplexity: 6.22829
# Epoch [3/3], Step [9600/12942], Loss: 2.0164, Perplexity: 7.51111
# Epoch [3/3], Step [9700/12942], Loss: 1.8977, Perplexity: 6.67087
# Epoch [3/3], Step [9800/12942], Loss: 1.9026, Perplexity: 6.70359
# Epoch [3/3], Step [9900/12942], Loss: 1.7915, Perplexity: 5.99820
# Epoch [3/3], Step [10000/12942], Loss: 2.5414, Perplexity: 12.6969
# Epoch [3/3], Step [10100/12942], Loss: 2.4912, Perplexity: 12.0763
# Epoch [3/3], Step [10200/12942], Loss: 1.9138, Perplexity: 6.77904
# Epoch [3/3], Step [10300/12942], Loss: 2.1951, Perplexity: 8.98081
# Epoch [3/3], Step [10400/12942], Loss: 1.9185, Perplexity: 6.81088
# Epoch [3/3], Step [10500/12942], Loss: 1.7962, Perplexity: 6.02697
# Epoch [3/3], Step [10600/12942], Loss: 2.5893, Perplexity: 13.3199
# Epoch [3/3], Step [10700/12942], Loss: 1.9363, Perplexity: 6.93289
# Epoch [3/3], Step [10800/12942], Loss: 1.7864, Perplexity: 5.96820
# Epoch [3/3], Step [10900/12942], Loss: 1.9532, Perplexity: 7.05121
# Epoch [3/3], Step [11000/12942], Loss: 2.3647, Perplexity: 10.6405
# Epoch [3/3], Step [11100/12942], Loss: 1.7422, Perplexity: 5.71013
# Epoch [3/3], Step [11200/12942], Loss: 1.8477, Perplexity: 6.34518
# Epoch [3/3], Step [11300/12942], Loss: 2.3382, Perplexity: 10.3627
# Epoch [3/3], Step [11400/12942], Loss: 2.1357, Perplexity: 8.46280
# Epoch [3/3], Step [11500/12942], Loss: 2.0474, Perplexity: 7.74753
# Epoch [3/3], Step [11600/12942], Loss: 2.0713, Perplexity: 7.93527
# Epoch [3/3], Step [11700/12942], Loss: 2.1515, Perplexity: 8.59760
# Epoch [3/3], Step [11800/12942], Loss: 1.9951, Perplexity: 7.35301
# Epoch [3/3], Step [11900/12942], Loss: 2.2574, Perplexity: 9.55847
# Epoch [3/3], Step [12000/12942], Loss: 2.3171, Perplexity: 10.1464
# Epoch [3/3], Step [12100/12942], Loss: 2.2633, Perplexity: 9.61504
# Epoch [3/3], Step [12200/12942], Loss: 2.2160, Perplexity: 9.17076
# Epoch [3/3], Step [12300/12942], Loss: 2.4488, Perplexity: 11.5742
# Epoch [3/3], Step [12400/12942], Loss: 2.1114, Perplexity: 8.25968
# Epoch [3/3], Step [12500/12942], Loss: 1.8268, Perplexity: 6.21384
# Epoch [3/3], Step [12600/12942], Loss: 1.7667, Perplexity: 5.85131
# Epoch [3/3], Step [12700/12942], Loss: 2.0951, Perplexity: 8.12661
# Epoch [3/3], Step [12800/12942], Loss: 1.8533, Perplexity: 6.38072
# Epoch [3/3], Step [12900/12942], Loss: 2.1404, Perplexity: 8.50328
# Epoch [3/3], Step [12942/12942], Loss: 2.0866, Perplexity: 8.05777

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
